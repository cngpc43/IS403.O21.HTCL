# %% [markdown]
# DXG

# %%
# 1. Import thư viện cần thiết

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU

# %%
# 1. Import thư viện cần thiết

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU

# %%
# 2. Đọc file csv và gắng index với giá Close
dxg = pd.read_csv('../DATA/DXG.csv')
qcg = pd.read_csv('../DATA/QCG.csv')
vhm = pd.read_csv('../DATA/VHM.csv')

def remove_commas_and_convert(x):
    return float(x.replace(',', ''))
# Áp dụng hàm cho toàn bộ DataFrame
dxg = dxg['Close'].apply(remove_commas_and_convert)
qcg = qcg['Close'].apply(remove_commas_and_convert)
vhm = vhm['Close'].apply(remove_commas_and_convert)

dxg1=dxg.reset_index()['Close']
qcg1=qcg.reset_index()['Close']
vhm1=vhm.reset_index()['Close']

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))

dxg1=scaler.fit_transform(np.array(dxg1).reshape(-1,1))
qcg1=scaler.fit_transform(np.array(qcg1).reshape(-1,1))
vhm1=scaler.fit_transform(np.array(vhm1).reshape(-1,1))

# %%
# 4. Chia train test
#DXG
dxg_train_size = int(0.75 * len(dxg1))
dxg_test_size = int(0.15 * len(dxg1))
dxg_val_size = len(dxg1) - dxg_train_size - dxg_test_size
dxg_train_data = dxg1[:dxg_train_size]
dxg_test_data = dxg1[dxg_train_size:dxg_train_size+dxg_test_size]
dxg_val_data = dxg1[dxg_train_size+dxg_test_size:]

#QCG
qcg_train_size = int(0.75 * len(qcg1))
qcg_test_size = int(0.15 * len(qcg1))
qcg_val_size = len(qcg1) - qcg_train_size - qcg_test_size
qcg_train_data = qcg1[:qcg_train_size]
qcg_test_data = qcg1[qcg_train_size:qcg_train_size+qcg_test_size]
qcg_val_data = qcg1[qcg_train_size+qcg_test_size:]

#VHM
vhm_train_size = int(0.75 * len(vhm1))
vhm_test_size = int(0.15 * len(vhm1))
vhm_val_size = len(vhm1) - vhm_train_size - vhm_test_size
vhm_train_data = vhm1[:vhm_train_size]
vhm_test_data = vhm1[vhm_train_size:vhm_train_size+vhm_test_size]
vhm_val_data = vhm1[vhm_train_size+vhm_test_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
#DXG
time_step = 100
dxg_X_train, dxg_y_train = create_dataset(dxg_train_data, time_step)
dxg_X_val, dxg_yval = create_dataset(dxg_val_data, time_step)
dxg_X_test, dxg_ytest = create_dataset(dxg_test_data, time_step)

#QCG
qcg_X_train, qcg_y_train = create_dataset(qcg_train_data, time_step)
qcg_X_val, qcg_yval = create_dataset(qcg_val_data, time_step)
qcg_X_test, qcg_ytest = create_dataset(qcg_test_data, time_step)


#VHM
vhm_X_train, vhm_y_train = create_dataset(vhm_train_data, time_step)
vhm_X_val, vhm_yval = create_dataset(vhm_val_data, time_step)
vhm_X_test, vhm_ytest = create_dataset(vhm_test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
dxg_X_train =dxg_X_train.reshape(dxg_X_train.shape[0],dxg_X_train.shape[1] , 1)
dxg_X_test = dxg_X_test.reshape(dxg_X_test.shape[0],dxg_X_test.shape[1] , 1)
dxg_X_val = dxg_X_val.reshape(dxg_X_val.shape[0],dxg_X_val.shape[1] , 1)

qcg_X_train =qcg_X_train.reshape(qcg_X_train.shape[0],qcg_X_train.shape[1] , 1)
qcg_X_test = qcg_X_test.reshape(qcg_X_test.shape[0],qcg_X_test.shape[1] , 1)
qcg_X_val = qcg_X_val.reshape(qcg_X_val.shape[0],qcg_X_val.shape[1] , 1)

vhm_X_train =vhm_X_train.reshape(vhm_X_train.shape[0],vhm_X_train.shape[1] , 1)
vhm_X_test = vhm_X_test.reshape(vhm_X_test.shape[0],vhm_X_test.shape[1] , 1)
vhm_X_val = vhm_X_val.reshape(vhm_X_val.shape[0],vhm_X_val.shape[1] , 1)

# %%
# 8. Define GRU Model

dxg_model = Sequential()
dxg_model.add(GRU(64, input_shape=(time_step, 1)))
dxg_model.add(Dense(1))
dxg_model.compile(optimizer='adam', loss='mean_squared_error')

qcg_model = Sequential()
qcg_model.add(GRU(64, input_shape=(time_step, 1)))
qcg_model.add(Dense(1))
qcg_model.compile(optimizer='adam', loss='mean_squared_error')

vhm_model = Sequential()
vhm_model.add(GRU(64, input_shape=(time_step, 1)))
vhm_model.add(Dense(1))
vhm_model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# c:\Users\Khang\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 9. Fit mô hình với dữ liệu train
dxg_model.fit(dxg_X_train,dxg_y_train,validation_data=(dxg_X_test,dxg_ytest),epochs=100,batch_size=64,verbose=1)
qcg_model.fit(qcg_X_train,qcg_y_train,validation_data=(qcg_X_test,qcg_ytest),epochs=100,batch_size=64,verbose=1)
vhm_model.fit(vhm_X_train,vhm_y_train,validation_data=(vhm_X_test,vhm_ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 0.0737 - val_loss: 0.0249
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0142 - val_loss: 0.0013
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0064 - val_loss: 0.0014
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0019 - val_loss: 1.6760e-04
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 8.4018e-04 - val_loss: 1.0251e-04
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.8789e-04 - val_loss: 1.3521e-04
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 8.3589e-04 - val_loss: 9.0855e-05
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 8.0587e-04 - val_loss: 8.9348e-05
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 7.5963e-04 - val_loss: 9.8654e-05
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 8.4588e-04 - val_loss: 1.7978e-04
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 8.9338e-04 - val_loss: 9.5517e-05
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 7.3103e-04 - val_loss: 8.7009e-05
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 7.0531e-04 - val_loss: 8.2681e-05
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 6.9764e-04 - val_loss: 1.1164e-04
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 7.3039e-04 - val_loss: 9.1418e-05
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 6.5132e-04 - val_loss: 7.7037e-05
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 7.0580e-04 - val_loss: 7.6366e-05
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 6.5298e-04 - val_loss: 7.5708e-05
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 6.0124e-04 - val_loss: 7.7394e-05
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 6.0589e-04 - val_loss: 8.2077e-05
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.5029e-04 - val_loss: 7.3709e-05
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 6.1712e-04 - val_loss: 7.3787e-05
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 5.4221e-04 - val_loss: 7.1750e-05
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 6.1416e-04 - val_loss: 6.9905e-05
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 6.1649e-04 - val_loss: 7.1843e-05
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.7125e-04 - val_loss: 6.8180e-05
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 5.8737e-04 - val_loss: 8.3874e-05
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.8116e-04 - val_loss: 6.8227e-05
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 5.2213e-04 - val_loss: 6.8969e-05
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 5.3254e-04 - val_loss: 6.5989e-05
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 5.3446e-04 - val_loss: 6.6216e-05
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 5.4756e-04 - val_loss: 8.3941e-05
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.2635e-04 - val_loss: 6.4162e-05
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 4.7659e-04 - val_loss: 6.5882e-05
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.2765e-04 - val_loss: 6.5148e-05
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 4.7644e-04 - val_loss: 7.3885e-05
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 5.1601e-04 - val_loss: 7.7227e-05
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.6670e-04 - val_loss: 6.7437e-05
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.9275e-04 - val_loss: 6.0492e-05
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.9909e-04 - val_loss: 6.1921e-05
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.9161e-04 - val_loss: 6.8205e-05
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.6216e-04 - val_loss: 6.4875e-05
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 5.1842e-04 - val_loss: 6.8927e-05
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 4.7722e-04 - val_loss: 6.6471e-05
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.9285e-04 - val_loss: 5.7414e-05
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 4.7835e-04 - val_loss: 6.9152e-05
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.8237e-04 - val_loss: 6.1016e-05
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 4.5840e-04 - val_loss: 5.6314e-05
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 4.5406e-04 - val_loss: 5.7161e-05
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 4.7986e-04 - val_loss: 5.6610e-05
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 4.2339e-04 - val_loss: 7.7109e-05
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 4.9505e-04 - val_loss: 6.3589e-05
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.7024e-04 - val_loss: 7.0608e-05
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.1636e-04 - val_loss: 6.1273e-05
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 4.5132e-04 - val_loss: 6.8017e-05
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.3267e-04 - val_loss: 5.4822e-05
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 4.6063e-04 - val_loss: 5.3981e-05
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 4.5144e-04 - val_loss: 5.3771e-05
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.4055e-04 - val_loss: 5.3664e-05
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.3371e-04 - val_loss: 5.5576e-05
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.2621e-04 - val_loss: 6.3166e-05
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.3878e-04 - val_loss: 5.2347e-05
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.3183e-04 - val_loss: 6.3428e-05
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.2778e-04 - val_loss: 6.4379e-05
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.4508e-04 - val_loss: 9.6852e-05
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.8734e-04 - val_loss: 8.3151e-05
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.2055e-04 - val_loss: 5.5903e-05
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 4.2508e-04 - val_loss: 5.2227e-05
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.7511e-04 - val_loss: 6.1097e-05
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 4.4486e-04 - val_loss: 1.0208e-04
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 4.7722e-04 - val_loss: 5.1919e-05
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 4.1735e-04 - val_loss: 5.5091e-05
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 4.1524e-04 - val_loss: 5.0096e-05
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 4.3522e-04 - val_loss: 4.9825e-05
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.4108e-04 - val_loss: 1.0398e-04
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.9180e-04 - val_loss: 5.4723e-05
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.4200e-04 - val_loss: 5.0834e-05
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.5736e-04 - val_loss: 6.9784e-05
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.5145e-04 - val_loss: 5.3703e-05
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.1526e-04 - val_loss: 4.9589e-05
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.1662e-04 - val_loss: 1.0628e-04
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.8407e-04 - val_loss: 5.1654e-05
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.0094e-04 - val_loss: 6.7930e-05
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.5729e-04 - val_loss: 4.7983e-05
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.3572e-04 - val_loss: 5.4060e-05
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 4.0765e-04 - val_loss: 4.8356e-05
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 4.2784e-04 - val_loss: 4.8074e-05
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 4.1995e-04 - val_loss: 5.4133e-05
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 4.0550e-04 - val_loss: 6.1172e-05
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 4.1483e-04 - val_loss: 5.4178e-05
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 4.5589e-04 - val_loss: 4.7605e-05
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 4.0724e-04 - val_loss: 4.7881e-05
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 3.6242e-04 - val_loss: 7.5688e-05
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.4812e-04 - val_loss: 4.7597e-05
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 3.7765e-04 - val_loss: 4.8370e-05
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.5458e-04 - val_loss: 5.2416e-05
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 4.4065e-04 - val_loss: 5.7158e-05
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 4.2573e-04 - val_loss: 4.6632e-05
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 3.9463e-04 - val_loss: 4.6273e-05
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.0582e-04 - val_loss: 4.7676e-05
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0392 - val_loss: 0.0262
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0094 - val_loss: 0.0021
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0050 - val_loss: 0.0024
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0018 - val_loss: 2.2530e-05
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0013 - val_loss: 1.6070e-05
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0012 - val_loss: 2.1387e-05
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0011 - val_loss: 2.4390e-05
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0012 - val_loss: 2.6428e-05
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 9.8254e-04 - val_loss: 3.2497e-05
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 9.5794e-04 - val_loss: 3.0711e-05
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 8.8209e-04 - val_loss: 1.7876e-05
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 9.0673e-04 - val_loss: 3.4900e-05
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 8.9094e-04 - val_loss: 3.2481e-05
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.4439e-04 - val_loss: 3.6854e-05
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 9.0743e-04 - val_loss: 1.1490e-05
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 7.0451e-04 - val_loss: 2.5106e-05
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.3585e-04 - val_loss: 1.0643e-05
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.4069e-04 - val_loss: 1.7868e-05
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 7.7187e-04 - val_loss: 1.2583e-05
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 8.2661e-04 - val_loss: 1.1035e-05
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 7.2089e-04 - val_loss: 1.0425e-05
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 6.4826e-04 - val_loss: 1.7413e-05
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 6.5100e-04 - val_loss: 1.1867e-05
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 6.6283e-04 - val_loss: 1.1448e-05
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 6.3949e-04 - val_loss: 6.9943e-05
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 7.6607e-04 - val_loss: 1.7425e-05
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 6.1452e-04 - val_loss: 3.8495e-05
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 6.1896e-04 - val_loss: 1.1452e-05
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 6.5231e-04 - val_loss: 1.5921e-05
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 6.0711e-04 - val_loss: 1.5451e-05
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.9448e-04 - val_loss: 1.4772e-05
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 5.9756e-04 - val_loss: 1.1278e-05
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.9195e-04 - val_loss: 2.8137e-05
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 6.4081e-04 - val_loss: 9.9196e-06
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 5.2230e-04 - val_loss: 1.0481e-05
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.7188e-04 - val_loss: 1.1388e-05
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 5.3577e-04 - val_loss: 1.0060e-05
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.9751e-04 - val_loss: 2.3519e-05
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.4586e-04 - val_loss: 1.2485e-05
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.0974e-04 - val_loss: 1.3327e-05
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 5.1564e-04 - val_loss: 1.9271e-05
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.6730e-04 - val_loss: 3.7468e-05
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.8759e-04 - val_loss: 3.5631e-05
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.8332e-04 - val_loss: 1.4375e-05
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4.7005e-04 - val_loss: 1.3597e-05
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.0594e-04 - val_loss: 1.3901e-05
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.9428e-04 - val_loss: 9.8356e-06
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.6699e-04 - val_loss: 3.4101e-05
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.6930e-04 - val_loss: 1.7228e-05
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.9102e-04 - val_loss: 2.5100e-05
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 4.4728e-04 - val_loss: 1.0539e-05
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.7419e-04 - val_loss: 7.0110e-05
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.2604e-04 - val_loss: 1.0592e-05
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.3374e-04 - val_loss: 3.0595e-05
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4.3016e-04 - val_loss: 1.1281e-05
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.5309e-04 - val_loss: 1.4609e-05
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.4254e-04 - val_loss: 1.0252e-05
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 4.2775e-04 - val_loss: 1.0345e-05
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 4.1884e-04 - val_loss: 1.0569e-05
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.4542e-04 - val_loss: 1.4620e-05
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.5102e-04 - val_loss: 9.8877e-06
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.0642e-04 - val_loss: 3.4151e-05
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 4.3802e-04 - val_loss: 9.7120e-06
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.5805e-04 - val_loss: 8.5991e-05
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.9198e-04 - val_loss: 1.4189e-05
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.4709e-04 - val_loss: 1.4231e-05
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.1980e-04 - val_loss: 1.5151e-05
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.8044e-04 - val_loss: 1.0965e-05
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.2388e-04 - val_loss: 9.7423e-06
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.8280e-04 - val_loss: 1.1250e-05
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.5447e-04 - val_loss: 3.8437e-05
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.9010e-04 - val_loss: 1.8446e-05
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 3.9959e-04 - val_loss: 4.4688e-05
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.9715e-04 - val_loss: 9.8065e-06
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 3.8388e-04 - val_loss: 1.5776e-05
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.2283e-04 - val_loss: 1.8746e-05
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 4.0053e-04 - val_loss: 1.0214e-05
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 4.0641e-04 - val_loss: 1.2738e-05
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 4.1571e-04 - val_loss: 1.5813e-05
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.4634e-04 - val_loss: 1.9463e-05
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 3.6446e-04 - val_loss: 9.9789e-06
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 3.7546e-04 - val_loss: 1.1303e-05
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.6714e-04 - val_loss: 9.8966e-06
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.0873e-04 - val_loss: 2.1174e-05
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.6118e-04 - val_loss: 2.9012e-05
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 3.8199e-04 - val_loss: 1.4435e-05
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3.7481e-04 - val_loss: 1.7726e-05
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.0601e-04 - val_loss: 1.0790e-05
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.9765e-04 - val_loss: 1.0355e-05
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.7938e-04 - val_loss: 1.0388e-05
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.5239e-04 - val_loss: 1.0378e-05
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 3.6657e-04 - val_loss: 1.0647e-05
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 3.6501e-04 - val_loss: 1.6296e-05
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.9224e-04 - val_loss: 1.0144e-05
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.3628e-04 - val_loss: 1.1034e-05
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.6319e-04 - val_loss: 1.0615e-05
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.8923e-04 - val_loss: 1.4387e-05
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.9894e-04 - val_loss: 1.0534e-05
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.2909e-04 - val_loss: 9.8718e-06
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.0609e-04 - val_loss: 8.4590e-05
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.3154 - val_loss: 0.0134
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0193 - val_loss: 0.0051
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0131 - val_loss: 0.0053
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0093 - val_loss: 0.0013
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0064 - val_loss: 0.0013
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0013 - val_loss: 9.9419e-04
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0015 - val_loss: 9.4434e-04
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0014 - val_loss: 9.3247e-04
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0013 - val_loss: 8.9742e-04
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0013 - val_loss: 9.5055e-04
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0012 - val_loss: 8.5446e-04
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0013 - val_loss: 8.3252e-04
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0011 - val_loss: 8.1893e-04
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0012 - val_loss: 8.5942e-04
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0012 - val_loss: 8.1201e-04
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 7.7851e-04
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0012 - val_loss: 7.7315e-04
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0012 - val_loss: 7.3931e-04
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - val_loss: 7.5910e-04
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0011 - val_loss: 7.2049e-04
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0011 - val_loss: 7.2784e-04
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0011 - val_loss: 7.1275e-04
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0010 - val_loss: 6.8542e-04
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 7.1432e-04
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - val_loss: 6.7586e-04
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0011 - val_loss: 6.6229e-04
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0012 - val_loss: 6.4045e-04
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - val_loss: 6.3112e-04
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0010 - val_loss: 6.2931e-04
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0010 - val_loss: 6.4059e-04
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0010 - val_loss: 6.1412e-04
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0010 - val_loss: 5.9663e-04
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0010 - val_loss: 5.9136e-04
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 9.5628e-04 - val_loss: 6.1404e-04
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 9.9686e-04 - val_loss: 6.0888e-04
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - val_loss: 5.8372e-04
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 9.6583e-04 - val_loss: 6.0968e-04
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 9.5591e-04 - val_loss: 5.8077e-04
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 9.1598e-04 - val_loss: 5.8328e-04
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.3004e-04 - val_loss: 5.8120e-04
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 9.8810e-04 - val_loss: 5.7303e-04
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.5417e-04 - val_loss: 5.3039e-04
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.7746e-04 - val_loss: 5.4342e-04
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.0725e-04 - val_loss: 5.2057e-04
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.0227e-04 - val_loss: 5.5429e-04
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 5.9674e-04
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0010 - val_loss: 5.3103e-04
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.4857e-04 - val_loss: 5.2031e-04
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.6175e-04 - val_loss: 5.4706e-04
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.7805e-04 - val_loss: 4.9341e-04
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.5238e-04 - val_loss: 4.9017e-04
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.5364e-04 - val_loss: 4.8529e-04
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.2763e-04 - val_loss: 4.8661e-04
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 8.6907e-04 - val_loss: 5.1284e-04
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.5587e-04 - val_loss: 4.7141e-04
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 8.6375e-04 - val_loss: 4.6384e-04
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.5062e-04 - val_loss: 4.7144e-04
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.4528e-04 - val_loss: 4.6977e-04
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 8.0567e-04 - val_loss: 4.7613e-04
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.6373e-04 - val_loss: 5.0552e-04
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 9.8303e-04 - val_loss: 5.2892e-04
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.6625e-04 - val_loss: 4.5803e-04
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.1831e-04 - val_loss: 4.7305e-04
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.2584e-04 - val_loss: 5.2238e-04
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 9.3320e-04 - val_loss: 4.7313e-04
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.6284e-04 - val_loss: 5.0376e-04
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.2542e-04 - val_loss: 5.2059e-04
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 8.8551e-04 - val_loss: 5.3658e-04
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.1231e-04 - val_loss: 4.3852e-04
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 9.5355e-04 - val_loss: 4.4912e-04
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.4281e-04 - val_loss: 4.4205e-04
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.8791e-04 - val_loss: 4.2355e-04
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 8.7878e-04 - val_loss: 4.2126e-04
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 8.5658e-04 - val_loss: 4.2846e-04
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 8.9011e-04 - val_loss: 4.5208e-04
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 8.8922e-04 - val_loss: 4.3409e-04
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 8.5166e-04 - val_loss: 4.6596e-04
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.1345e-04 - val_loss: 4.3824e-04
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 8.0160e-04 - val_loss: 4.0921e-04
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 8.2747e-04 - val_loss: 3.9671e-04
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 8.7034e-04 - val_loss: 6.5138e-04
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 9.8618e-04 - val_loss: 4.8828e-04
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 8.3733e-04 - val_loss: 5.4959e-04
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 7.8161e-04 - val_loss: 4.8765e-04
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 8.4512e-04 - val_loss: 3.9168e-04
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 8.1691e-04 - val_loss: 3.9882e-04
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 7.9590e-04 - val_loss: 4.1814e-04
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 7.9165e-04 - val_loss: 4.0209e-04
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 7.5007e-04 - val_loss: 4.0305e-04
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 8.4943e-04 - val_loss: 4.0750e-04

# %%
# 10. Dự báo dữ liệu test, val
dxg_train_predict=dxg_model.predict(dxg_X_train)
dxg_y_pred=dxg_model.predict(dxg_X_test)
dxg_y_pred_val=dxg_model.predict(dxg_X_val)

qcg_train_predict=qcg_model.predict(qcg_X_train)
qcg_y_pred=qcg_model.predict(qcg_X_test)
qcg_y_pred_val=qcg_model.predict(qcg_X_val)

vhm_train_predict=vhm_model.predict(vhm_X_train)
vhm_y_pred=vhm_model.predict(vhm_X_test)
vhm_y_pred_val=vhm_model.predict(vhm_X_val)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
dxg_train_predict=scaler.inverse_transform(dxg_train_predict)
dxg_y_pred=scaler.inverse_transform(dxg_y_pred)
dxg_y_pred_val=scaler.inverse_transform(dxg_y_pred_val)

qcg_train_predict=scaler.inverse_transform(qcg_train_predict)
qcg_y_pred=scaler.inverse_transform(qcg_y_pred)
qcg_y_pred_val=scaler.inverse_transform(qcg_y_pred_val)

vhm_train_predict=scaler.inverse_transform(vhm_train_predict)
vhm_y_pred=scaler.inverse_transform(vhm_y_pred)
vhm_y_pred_val=scaler.inverse_transform(vhm_y_pred_val)

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
dxg_valid_rmse = np.sqrt(np.mean((dxg_y_pred_val - dxg_yval)**2))
dxg_test_rmse = np.sqrt(np.mean((dxg_y_pred - dxg_ytest)**2))

qcg_valid_rmse = np.sqrt(np.mean((qcg_y_pred_val - qcg_yval)**2))
qcg_test_rmse = np.sqrt(np.mean((qcg_y_pred - qcg_ytest)**2))

vhm_valid_rmse = np.sqrt(np.mean((vhm_y_pred_val - vhm_yval)**2))
vhm_test_rmse = np.sqrt(np.mean((vhm_y_pred - vhm_ytest)**2))

print('DXG')
print('Validation RMSE:', dxg_valid_rmse)
print('Testing RMSE:', dxg_test_rmse)
print('\n')

print('QCG')
print('Validation RMSE:', qcg_valid_rmse)
print('Testing RMSE:', qcg_test_rmse)
print('\n')

print('VHM')
print('Validation RMSE:', vhm_valid_rmse)
print('Testing RMSE:', vhm_test_rmse)
# Out:
# DXG
# Validation RMSE: 50218.2001653143
# Testing RMSE: 47008.98792771596
#
#
# QCG
# Validation RMSE: 43548.70530552746
# Testing RMSE: 40901.62737382939
#
#
# VHM
# Validation RMSE: 69452.39942595539
# Testing RMSE: 68722.9824192824

# %%
# 13. Dự báo 30 ngày tiếp theo
x_input=dxg_val_data[60:].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

dxg_lst_output=[]
n_steps=66
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = dxg_model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        dxg_lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = dxg_model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        dxg_lst_output.extend(yhat.tolist())
        i=i+1
# Out:
# [0.26516044]
# 67
# [0.26516044]
# 68
# [0.26516044]
# 69
# [0.26516044]
# 70
# [0.26516044]
# 71
# [0.26516044]
# 72
# [0.26516044]
# 73
# [0.26516044]
# 74
# [0.26516044]
# 75
# [0.26516044]
# 76
# [0.26516044]
# 77
# [0.26516044]
# 78
# [0.26516044]
# 79
# [0.26516044]
# 80
# [0.26516044]
# 81
# [0.26516044]
# 82
# [0.26516044]
# 83
# [0.26516044]
# 84
# [0.26516044]
# 85
# [0.26516044]
# 86
# [0.26516044]
# 87
# [0.26516044]
# 88
# [0.26516044]
# 89
# [0.26516044]
# 90
# [0.26516044]
# 91
# [0.26516044]
# 92
# [0.26516044]
# 93
# [0.26516044]
# 94
# [0.26516044]
# 95
# [0.26516044]
# 96

# %%
# 13. Dự báo 30 ngày tiếp theo
x_input=qcg_val_data[60:].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

qcg_lst_output=[]
n_steps=66
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = qcg_model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        qcg_lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = qcg_model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        qcg_lst_output.extend(yhat.tolist())
        i=i+1
# Out:
# [0.06601677]
# 67
# [0.06601677]
# 68
# [0.06601677]
# 69
# [0.06601677]
# 70
# [0.06601677]
# 71
# [0.06601677]
# 72
# [0.06601677]
# 73
# [0.06601677]
# 74
# [0.06601677]
# 75
# [0.06601677]
# 76
# [0.06601677]
# 77
# [0.06601677]
# 78
# [0.06601677]
# 79
# [0.06601677]
# 80
# [0.06601677]
# 81
# [0.06601677]
# 82
# [0.06601677]
# 83
# [0.06601677]
# 84
# [0.06601677]
# 85
# [0.06601677]
# 86
# [0.06601677]
# 87
# [0.06601677]
# 88
# [0.06601677]
# 89
# [0.06601677]
# 90
# [0.06601677]
# 91
# [0.06601677]
# 92
# [0.06601677]
# 93
# [0.06601677]
# 94
# [0.06601677]
# 95
# [0.06601677]
# 96

# %%
# 13. Dự báo 30 ngày tiếp theo
x_input=vhm_val_data[60:].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

vhm_lst_output=[]
n_steps=66
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = vhm_model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        vhm_lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = vhm_model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        vhm_lst_output.extend(yhat.tolist())
        i=i+1
# Out:
# [0.61295795]
# 67
# [0.61295795]
# 68
# [0.61295795]
# 69
# [0.61295795]
# 70
# [0.61295795]
# 71
# [0.61295795]
# 72
# [0.61295795]
# 73
# [0.61295795]
# 74
# [0.61295795]
# 75
# [0.61295795]
# 76
# [0.61295795]
# 77
# [0.61295795]
# 78
# [0.61295795]
# 79
# [0.61295795]
# 80
# [0.61295795]
# 81
# [0.61295795]
# 82
# [0.61295795]
# 83
# [0.61295795]
# 84
# [0.61295795]
# 85
# [0.61295795]
# 86
# [0.61295795]
# 87
# [0.61295795]
# 88
# [0.61295795]
# 89
# [0.61295795]
# 90
# [0.61295795]
# 91
# [0.61295795]
# 92
# [0.61295795]
# 93
# [0.61295795]
# 94
# [0.61295795]
# 95
# [0.61295795]
# 96

# %%
# 14.Vẽ hình
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

#DXG
dxg_train_data_index = pd.RangeIndex(start=0, stop=dxg_train_size, step=1)
axs[0].plot(scaler.inverse_transform(dxg_train_data))
dxg_test_data_index = pd.RangeIndex(start=dxg_train_size, stop=dxg_train_size+dxg_test_size, step=1)
axs[0].plot(dxg_test_data_index,scaler.inverse_transform(dxg_test_data))
dxg_test_data_index = pd.RangeIndex(start=dxg_train_size+101, stop=dxg_train_size+dxg_test_size, step=1)
axs[0].plot(dxg_test_data_index,(dxg_y_pred))
dxg_val_data_index = pd.RangeIndex(start=dxg_train_size+dxg_test_size, stop=dxg_train_size+dxg_test_size+dxg_val_size, step=1)
axs[0].plot(dxg_val_data_index,scaler.inverse_transform(dxg_val_data))
dxg_val_data_index = pd.RangeIndex(start=dxg_train_size+dxg_test_size+101, stop=dxg_train_size+dxg_test_size+dxg_val_size, step=1)
axs[0].plot(dxg_val_data_index,dxg_y_pred_val)
dxg_predict_data_index = pd.RangeIndex(start=len(dxg1)-1, stop=len(dxg1)+29, step=1)
axs[0].plot(dxg_predict_data_index,scaler.inverse_transform(dxg_lst_output))
axs[0].legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])


#QCG
qcg_train_data_index = pd.RangeIndex(start=0, stop=qcg_train_size, step=1)
axs[1].plot(scaler.inverse_transform(qcg_train_data))
qcg_test_data_index = pd.RangeIndex(start=qcg_train_size, stop=qcg_train_size+qcg_test_size, step=1)
axs[1].plot(qcg_test_data_index,scaler.inverse_transform(qcg_test_data))
qcg_test_data_index = pd.RangeIndex(start=qcg_train_size+101, stop=qcg_train_size+qcg_test_size, step=1)
axs[1].plot(qcg_test_data_index,(qcg_y_pred))
qcg_val_data_index = pd.RangeIndex(start=qcg_train_size+qcg_test_size, stop=qcg_train_size+qcg_test_size+qcg_val_size, step=1)
axs[1].plot(qcg_val_data_index,scaler.inverse_transform(qcg_val_data))
qcg_val_data_index = pd.RangeIndex(start=qcg_train_size+qcg_test_size+101, stop=qcg_train_size+qcg_test_size+qcg_val_size, step=1)
axs[1].plot(qcg_val_data_index,qcg_y_pred_val)
qcg_predict_data_index = pd.RangeIndex(start=len(qcg1)-1, stop=len(qcg1)+29, step=1)
axs[1].plot(qcg_predict_data_index,scaler.inverse_transform(qcg_lst_output))
axs[1].legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])

#VHM
vhm_train_data_index = pd.RangeIndex(start=0, stop=vhm_train_size, step=1)
axs[2].plot(scaler.inverse_transform(vhm_train_data))
vhm_test_data_index = pd.RangeIndex(start=vhm_train_size, stop=vhm_train_size+vhm_test_size, step=1)
axs[2].plot(vhm_test_data_index,scaler.inverse_transform(vhm_test_data))
vhm_test_data_index = pd.RangeIndex(start=vhm_train_size+101, stop=vhm_train_size+vhm_test_size, step=1)
axs[2].plot(vhm_test_data_index,(vhm_y_pred))
vhm_val_data_index = pd.RangeIndex(start=vhm_train_size+vhm_test_size, stop=vhm_train_size+vhm_test_size+vhm_val_size, step=1)
axs[2].plot(vhm_val_data_index,scaler.inverse_transform(vhm_val_data))
vhm_val_data_index = pd.RangeIndex(start=vhm_train_size+vhm_test_size+101, stop=vhm_train_size+vhm_test_size+vhm_val_size, step=1)
axs[2].plot(vhm_val_data_index,vhm_y_pred_val)
vhm_predict_data_index = pd.RangeIndex(start=len(vhm1)-1, stop=len(vhm1)+29, step=1)
axs[2].plot(vhm_predict_data_index,scaler.inverse_transform(vhm_lst_output))
axs[2].legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])


axs[0].set_xlabel('DXG',fontsize=20)
axs[1].set_xlabel('QCG',fontsize=20)
axs[2].set_xlabel('VHM',fontsize=20)
plt.tight_layout()
plt.show()
