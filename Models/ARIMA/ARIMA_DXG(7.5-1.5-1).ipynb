# %%
import pandas as pd

# Load data from CSV file
data = pd.read_csv('../../DATASET/DXG.csv')

# Preprocess data
# Covert volume from string to number
def convert_volume_to_number(volume_str):
    if volume_str[-1] == 'K':
        return int(float(volume_str[:-1]) * 1000)
    elif volume_str[-1] == 'M':
        return int(float(volume_str[:-1]) * 1000000)
    elif volume_str[-1] == 'B':
        return int(float(volume_str[:-1]) * 1000000000)
    else:
        return int(volume_str)
    
# Apply convert_volume_to_number function to Volume column
data["Volume"] = data["Volume"].apply(convert_volume_to_number)

# Covert change % from string to number
def convert_change_to_number(change_str):
    new_change = float(change_str.strip('%')) / 100
    return new_change

# Apply convert_change_to_number function to Change % column
data["Change %"] = data["Change %"].apply(convert_change_to_number)

# Function to convert string to number
def convert_str_to_number(str):
    return float(str.replace(',', ''))


# Apply convert_str_to_number function to Close, Open, High, Low columns
data['Close'] = data['Close'].apply(convert_str_to_number)
data['Open'] = data['Open'].apply(convert_str_to_number)
data['High'] = data['High'].apply(convert_str_to_number)
data['Low'] = data['Low'].apply(convert_str_to_number)
data
# Out:
#             Date    Close     Open     High      Low    Volume  Change %
# 0       1/3/2024  18450.0  18300.0  18500.0  18150.0   9350000    0.0110
# 1     29/02/2024  18250.0  18150.0  18400.0  18050.0  13440000    0.0111
# 2     28/02/2024  18050.0  18300.0  18350.0  18000.0   6990000   -0.0082
# 3     27/02/2024  18200.0  18000.0  18300.0  17800.0  11250000    0.0196
# 4     26/02/2024  17850.0  18100.0  18150.0  17650.0   9100000   -0.0165
# ...          ...      ...      ...      ...      ...       ...       ...
# 1247    7/3/2019  17092.0  17912.4  17912.4  17092.0   3840000   -0.0329
# 1248    6/3/2019  17673.2  17502.2  17741.5  17365.5   1640000    0.0098
# 1249    5/3/2019  17502.2  17775.7  17912.4  17365.5   3490000   -0.0173
# 1250    4/3/2019  17809.9  17228.8  17878.3  17092.0   5540000    0.0441
# 1251    1/3/2019  17057.8  16750.2  17057.8  16750.2   1270000    0.0184
#
# [1252 rows x 7 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
df = data
df = df[['Close']]
df = df.dropna() # Drop missing values
df = df.reset_index(drop=True) # Reset the index

# Split the data into training, testing, and validation sets
train_size = int(0.75 * len(df))
test_size = int(0.15 * len(df))
val_size = len(df) - train_size - test_size

train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
val_data = df[train_size+test_size:]

# %%
import sys, os
try:
    import pdarima as pda
except:
    os.system("pip install pmdarima")

from pmdarima.arima import auto_arima
# Out:
# Requirement already satisfied: pmdarima in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pmdarima) (3.0.10)
# Requirement already satisfied: numpy>=1.21.2 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pmdarima) (2.2.1)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pmdarima) (1.5.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pmdarima) (1.12.0)
# Requirement already satisfied: statsmodels>=0.13.2 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pmdarima) (0.14.1)
# Requirement already satisfied: urllib3 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pmdarima) (2.2.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pmdarima) (65.5.0)
# Requirement already satisfied: packaging>=17.1 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pmdarima) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from scikit-learn>=0.22->pmdarima) (3.3.0)
# Requirement already satisfied: patsy>=0.5.4 in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in /Users/willphan_43/.pyenv/versions/3.11.3/lib/python3.11/site-packages (from patsy>=0.5.4->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Close'])

# Find the best ARIMA model using auto_arima
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True, error_action='ignore', suppress_warnings=True)

# Fit the model
model.fit(y_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=15034.604, Time=0.62 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=15041.345, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=15035.896, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=15035.199, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=15039.490, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=15035.212, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=15035.179, Time=0.16 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=15036.507, Time=0.84 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=15036.512, Time=1.18 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=15033.270, Time=0.10 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=15035.278, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=15036.078, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=15031.384, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=15033.337, Time=0.10 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=15034.036, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=15033.287, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=15033.326, Time=0.08 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=15033.420, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=15034.220, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=15032.774, Time=0.13 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 3.752 seconds
# ARIMA(order=(1, 1, 1), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
# 
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Close'])
y_pred = model.predict(n_periods=len(y_test))

x_val= np.array(val_data.index).reshape(-1, 1)
y_val = np.array(val_data['Close'])
y_pred_val =  model.predict(n_periods=len(y_val))

# %%
# Predict the closing prices for the next 30 days
last_index =  df.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

# Create an array of 30 consecutive integers starting from last_index
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(n_periods=len(x_next_30_days))

# Print the predicted closing prices for the next 30 days
print('Predicted closing prices for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted closing prices for the next 30 days:
# [9929.71558394 9920.00208709 9925.64664138 9922.3665669  9924.27263212
#  9923.16500952 9923.80865372 9923.43462934 9923.65197649 9923.52567514
#  9923.59906939 9923.55641968 9923.58120361 9923.56680156 9923.57517065
#  9923.57030734 9923.57313343 9923.57149118 9923.5724455  9923.57189094
#  9923.5722132  9923.57202593 9923.57213475 9923.57207151 9923.57210826
#  9923.57208691 9923.57209932 9923.57209211 9923.5720963  9923.57209386]

# %%
# Convert y_val and y_test to numeric
y_val = pd.to_numeric(y_val, errors='coerce')
y_test = pd.to_numeric(y_test, errors='coerce')

# Calculate RMSE
valid_rmse = np.sqrt(np.mean((y_pred_val - y_val)**2))
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))

print('Validation RMSE:', valid_rmse)
print('Testing RMSE:', test_rmse)
# Out:
# Validation RMSE: 4014.021031250529
# Testing RMSE: 2716.6521473571283

# %%
# Calculate RMSE
valid_rmse = np.sqrt(np.mean((y_pred_val - y_val)**2))
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('Validation RMSE:', valid_rmse)
print('Testing RMSE:', test_rmse)

# Plot the data
plt.plot(train_data.index, train_data['Close'])
plt.plot(test_data.index, test_data['Close'])
plt.plot(test_data.index, y_pred)
plt.plot(val_data.index, y_pred_val)
plt.plot(last_data,y_next_30_days)
plt.legend(['Train', 'Test', 'Predictions','Validate','Next30Day'])
plt.show()
# Out:
# Validation RMSE: 4014.021031250529
# Testing RMSE: 2716.6521473571283

# %%
test_data.index
# Out:
# RangeIndex(start=939, stop=1126, step=1)

# %%
# Calculate MAPE
def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Calculate MDA
def calculate_mda(y_true, y_pred):
    y_true_diff = np.diff(y_true)
    y_pred_diff = np.diff(y_pred)
    correct_direction = np.sign(y_true_diff) == np.sign(y_pred_diff)
    return np.mean(correct_direction) * 100

# Calculate MAPE, RMSE and MDA
valid_rmse = np.sqrt(np.mean((y_pred_val - y_val) ** 2))
test_rmse = np.sqrt(np.mean((y_pred - y_test) ** 2))
valid_mape = calculate_mape(y_val, y_pred_val)
test_mape = calculate_mape(y_test, y_pred)
valid_mda = calculate_mda(y_val, y_pred_val)
test_mda = calculate_mda(y_test, y_pred)

# Print the performance metrics
print('Validation RMSE:', valid_rmse)
print('Testing RMSE:', test_rmse)
print('Validation MAPE:', valid_mape)
print('Testing MAPE:', test_mape)
print('Validation MDA:', valid_mda)
print('Testing MDA:', test_mda)
# Out:
# Validation RMSE: 4014.021031250529
# Testing RMSE: 2716.6521473571283
# Validation MAPE: 25.852538938892778
# Testing MAPE: 19.087641376409664
# Validation MDA: 26.400000000000002
# Testing MDA: 17.741935483870968
