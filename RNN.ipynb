# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN

# %%
# 2. Đọc file csv và gắng index với giá Close
dxg = pd.read_csv('./DATA/DXG.csv')
qcg = pd.read_csv('./DATA/QCG.csv')
vhm = pd.read_csv('./DATA/VHM.csv')

def remove_commas_and_convert(x):
    return float(x.replace(',', ''))
# Áp dụng hàm cho toàn bộ DataFrame
dxg = dxg['Close'].apply(remove_commas_and_convert)
qcg = qcg['Close'].apply(remove_commas_and_convert)
vhm = vhm['Close'].apply(remove_commas_and_convert)

dxg1=dxg.reset_index()['Close']
qcg1=qcg.reset_index()['Close']
vhm1=vhm.reset_index()['Close']

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))

dxg1=scaler.fit_transform(np.array(dxg1).reshape(-1,1))
qcg1=scaler.fit_transform(np.array(qcg1).reshape(-1,1))
vhm1=scaler.fit_transform(np.array(vhm1).reshape(-1,1))

# %%
# 4. Chia train test
#DXG
dxg_train_size = int(0.7 * len(dxg1))
dxg_test_size = int(0.2 * len(dxg1))
dxg_val_size = len(dxg1) - dxg_train_size - dxg_test_size
dxg_train_data = dxg1[:dxg_train_size]
dxg_test_data = dxg1[dxg_train_size:dxg_train_size+dxg_test_size]
dxg_val_data = dxg1[dxg_train_size+dxg_test_size:]

#QCG
qcg_train_size = int(0.7 * len(qcg1))
qcg_test_size = int(0.2 * len(qcg1))
qcg_val_size = len(qcg1) - qcg_train_size - qcg_test_size
qcg_train_data = qcg1[:qcg_train_size]
qcg_test_data = qcg1[qcg_train_size:qcg_train_size+qcg_test_size]
qcg_val_data = qcg1[qcg_train_size+qcg_test_size:]

#VHM
vhm_train_size = int(0.7 * len(vhm1))
vhm_test_size = int(0.2 * len(vhm1))
vhm_val_size = len(vhm1) - vhm_train_size - vhm_test_size
vhm_train_data = vhm1[:vhm_train_size]
vhm_test_data = vhm1[vhm_train_size:vhm_train_size+vhm_test_size]
vhm_val_data = vhm1[vhm_train_size+vhm_test_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
#DXG
time_step = 100
dxg_X_train, dxg_y_train = create_dataset(dxg_train_data, time_step)
dxg_X_val, dxg_yval = create_dataset(dxg_val_data, time_step)
dxg_X_test, dxg_ytest = create_dataset(dxg_test_data, time_step)

#QCG
qcg_X_train, qcg_y_train = create_dataset(qcg_train_data, time_step)
qcg_X_val, qcg_yval = create_dataset(qcg_val_data, time_step)
qcg_X_test, qcg_ytest = create_dataset(qcg_test_data, time_step)


#VHM
vhm_X_train, vhm_y_train = create_dataset(vhm_train_data, time_step)
vhm_X_val, vhm_yval = create_dataset(vhm_val_data, time_step)
vhm_X_test, vhm_ytest = create_dataset(vhm_test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
dxg_X_train =dxg_X_train.reshape(dxg_X_train.shape[0],dxg_X_train.shape[1] , 1)
dxg_X_test = dxg_X_test.reshape(dxg_X_test.shape[0],dxg_X_test.shape[1] , 1)
dxg_X_val = dxg_X_val.reshape(dxg_X_val.shape[0],dxg_X_val.shape[1] , 1)

qcg_X_train =qcg_X_train.reshape(qcg_X_train.shape[0],qcg_X_train.shape[1] , 1)
qcg_X_test = qcg_X_test.reshape(qcg_X_test.shape[0],qcg_X_test.shape[1] , 1)
qcg_X_val = qcg_X_val.reshape(qcg_X_val.shape[0],qcg_X_val.shape[1] , 1)

vhm_X_train =vhm_X_train.reshape(vhm_X_train.shape[0],vhm_X_train.shape[1] , 1)
vhm_X_test = vhm_X_test.reshape(vhm_X_test.shape[0],vhm_X_test.shape[1] , 1)
vhm_X_val = vhm_X_val.reshape(vhm_X_val.shape[0],vhm_X_val.shape[1] , 1)

# %%
# 8. Define LSTM Model

dxg_model = Sequential()
dxg_model.add(SimpleRNN(50, input_shape=(time_step, 1)))
dxg_model.add(Dense(1))
dxg_model.compile(optimizer='adam', loss='mean_squared_error')

qcg_model = Sequential()
qcg_model.add(SimpleRNN(50, input_shape=(time_step, 1)))
qcg_model.add(Dense(1))
qcg_model.compile(optimizer='adam', loss='mean_squared_error')

vhm_model = Sequential()
vhm_model.add(SimpleRNN(50, input_shape=(time_step, 1)))
vhm_model.add(Dense(1))
vhm_model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# c:\Users\Khang\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 9. Fit mô hình với dữ liệu train
dxg_model.fit(dxg_X_train,dxg_y_train,validation_data=(dxg_X_test,dxg_ytest),epochs=100,batch_size=64,verbose=1)
qcg_model.fit(qcg_X_train,qcg_y_train,validation_data=(qcg_X_test,qcg_ytest),epochs=100,batch_size=64,verbose=1)
vhm_model.fit(vhm_X_train,vhm_y_train,validation_data=(vhm_X_test,vhm_ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0586 - val_loss: 0.0030
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0088 - val_loss: 0.0019
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0030 - val_loss: 8.7623e-04
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0019 - val_loss: 7.5320e-04
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - val_loss: 7.1608e-04
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - val_loss: 5.5304e-04
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 5.0647e-04
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 4.7799e-04
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013 - val_loss: 4.1837e-04
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0013 - val_loss: 3.9217e-04
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013 - val_loss: 4.0940e-04
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 4.2330e-04
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0012 - val_loss: 3.7892e-04
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0012 - val_loss: 3.1852e-04
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011 - val_loss: 2.9051e-04
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.7203e-04 - val_loss: 2.8925e-04
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 9.9862e-04 - val_loss: 2.8142e-04
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.8990e-04 - val_loss: 2.6641e-04
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 9.7041e-04 - val_loss: 2.6727e-04
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.8814e-04 - val_loss: 2.5322e-04
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0010 - val_loss: 2.4737e-04
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.7227e-04 - val_loss: 2.4034e-04
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.9636e-04 - val_loss: 2.1405e-04
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.7599e-04 - val_loss: 2.1637e-04
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.3573e-04 - val_loss: 2.3713e-04
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8033e-04 - val_loss: 2.1513e-04
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.6196e-04 - val_loss: 2.2735e-04
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.2548e-04 - val_loss: 1.9113e-04
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4489e-04 - val_loss: 2.0902e-04
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.9944e-04 - val_loss: 1.7660e-04
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5919e-04 - val_loss: 1.8317e-04
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.5939e-04 - val_loss: 1.8277e-04
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.1519e-04 - val_loss: 2.0798e-04
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.0744e-04 - val_loss: 2.2540e-04
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.5863e-04 - val_loss: 1.8711e-04
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.5677e-04 - val_loss: 1.5648e-04
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4323e-04 - val_loss: 1.4875e-04
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4115e-04 - val_loss: 1.6180e-04
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.1320e-04 - val_loss: 1.5424e-04
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0859e-04 - val_loss: 1.3970e-04
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6886e-04 - val_loss: 1.4721e-04
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0088e-04 - val_loss: 1.6501e-04
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1464e-04 - val_loss: 1.3691e-04
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.2177e-04 - val_loss: 1.3001e-04
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3204e-04 - val_loss: 1.2877e-04
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.5093e-04 - val_loss: 1.2707e-04
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.9440e-04 - val_loss: 1.6680e-04
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.2397e-04 - val_loss: 1.2364e-04
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.7000e-04 - val_loss: 1.2119e-04
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.0444e-04 - val_loss: 1.1460e-04
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.1429e-04 - val_loss: 1.1536e-04
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3318e-04 - val_loss: 1.1463e-04
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6887e-04 - val_loss: 1.1230e-04
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3663e-04 - val_loss: 1.3368e-04
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1306e-04 - val_loss: 1.3204e-04
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0866e-04 - val_loss: 1.3949e-04
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5418e-04 - val_loss: 1.0904e-04
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6272e-04 - val_loss: 1.1040e-04
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6797e-04 - val_loss: 1.3576e-04
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.6865e-04 - val_loss: 1.6500e-04
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5480e-04 - val_loss: 1.0355e-04
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.4892e-04 - val_loss: 1.1213e-04
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9318e-04 - val_loss: 1.2842e-04
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8290e-04 - val_loss: 1.0715e-04
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6417e-04 - val_loss: 1.4548e-04
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3080e-04 - val_loss: 1.0244e-04
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5753e-04 - val_loss: 1.0120e-04
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3675e-04 - val_loss: 9.6065e-05
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.3480e-04 - val_loss: 1.0907e-04
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5167e-04 - val_loss: 9.7567e-05
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.6489e-04 - val_loss: 9.6230e-05
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5289e-04 - val_loss: 9.2677e-05
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3871e-04 - val_loss: 9.2129e-05
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5618e-04 - val_loss: 1.1218e-04
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4485e-04 - val_loss: 1.6976e-04
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9959e-04 - val_loss: 9.2556e-05
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.5562e-04 - val_loss: 1.1020e-04
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.4296e-04 - val_loss: 9.2683e-05
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3236e-04 - val_loss: 9.5040e-05
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.3628e-04 - val_loss: 1.8458e-04
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3676e-04 - val_loss: 1.0330e-04
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3515e-04 - val_loss: 9.2262e-05
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.6993e-04 - val_loss: 9.1348e-05
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 5.0532e-04 - val_loss: 1.0058e-04
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.6733e-04 - val_loss: 1.1136e-04
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.3518e-04 - val_loss: 1.1760e-04
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.5210e-04 - val_loss: 8.2792e-05
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.0400e-04 - val_loss: 8.4879e-05
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.3598e-04 - val_loss: 8.3274e-05
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.5491e-04 - val_loss: 8.6538e-05
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.3975e-04 - val_loss: 8.6464e-05
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.0081e-04 - val_loss: 1.0416e-04
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9224e-04 - val_loss: 1.3022e-04
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1961e-04 - val_loss: 1.0165e-04
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5330e-04 - val_loss: 8.5184e-05
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1279e-04 - val_loss: 1.0089e-04
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3320e-04 - val_loss: 8.2965e-05
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3402e-04 - val_loss: 8.6502e-05
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5400e-04 - val_loss: 9.3657e-05
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4024e-04 - val_loss: 8.4308e-05
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0214 - val_loss: 7.6573e-04
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - val_loss: 8.8132e-04
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 8.3442e-04
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.1486e-04 - val_loss: 7.3660e-04
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.4254e-04 - val_loss: 6.7867e-04
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - val_loss: 6.5585e-04
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5413e-04 - val_loss: 5.8049e-04
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.2339e-04 - val_loss: 8.0411e-04
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - val_loss: 5.9179e-04
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.9630e-04 - val_loss: 4.8938e-04
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.9448e-04 - val_loss: 6.7781e-04
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.4152e-04 - val_loss: 5.5829e-04
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.7600e-04 - val_loss: 4.7962e-04
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.8869e-04 - val_loss: 4.6721e-04
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.3955e-04 - val_loss: 4.3976e-04
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7332e-04 - val_loss: 4.2715e-04
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.3439e-04 - val_loss: 4.3445e-04
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.0609e-04 - val_loss: 4.0050e-04
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.7867e-04 - val_loss: 3.9704e-04
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.5347e-04 - val_loss: 4.5503e-04
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.3236e-04 - val_loss: 3.3782e-04
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.5053e-04 - val_loss: 3.7500e-04
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4488e-04 - val_loss: 4.8505e-04
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0246e-04 - val_loss: 4.1894e-04
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.6003e-04 - val_loss: 3.1065e-04
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.9841e-04 - val_loss: 3.2512e-04
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8847e-04 - val_loss: 3.3597e-04
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4188e-04 - val_loss: 3.5406e-04
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.4514e-04 - val_loss: 4.0753e-04
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6337e-04 - val_loss: 3.8840e-04
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4439e-04 - val_loss: 3.4751e-04
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8756e-04 - val_loss: 3.0619e-04
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7297e-04 - val_loss: 3.1062e-04
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.6043e-04 - val_loss: 3.1085e-04
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3281e-04 - val_loss: 3.0623e-04
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8470e-04 - val_loss: 3.0169e-04
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6025e-04 - val_loss: 2.8157e-04
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7523e-04 - val_loss: 2.6868e-04
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1697e-04 - val_loss: 2.8465e-04
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8750e-04 - val_loss: 2.9827e-04
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7852e-04 - val_loss: 3.2032e-04
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.3908e-04 - val_loss: 3.9915e-04
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.6441e-04 - val_loss: 2.9373e-04
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 5.2867e-04 - val_loss: 2.5516e-04
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.2538e-04 - val_loss: 2.5888e-04
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.4722e-04 - val_loss: 3.4335e-04
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.2815e-04 - val_loss: 2.4489e-04
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.8746e-04 - val_loss: 2.8473e-04
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.4316e-04 - val_loss: 2.4044e-04
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.0950e-04 - val_loss: 3.6649e-04
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.2241e-04 - val_loss: 2.3768e-04
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.6172e-04 - val_loss: 2.2679e-04
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.2892e-04 - val_loss: 2.2342e-04
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.0540e-04 - val_loss: 2.9481e-04
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.1072e-04 - val_loss: 2.4296e-04
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.3865e-04 - val_loss: 2.3489e-04
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.7358e-04 - val_loss: 2.1472e-04
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8678e-04 - val_loss: 2.1092e-04
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7170e-04 - val_loss: 2.2072e-04
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7428e-04 - val_loss: 2.4006e-04
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8783e-04 - val_loss: 3.1415e-04
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.2122e-04 - val_loss: 3.6134e-04
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1040e-04 - val_loss: 2.4709e-04
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.8306e-04 - val_loss: 2.1520e-04
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7981e-04 - val_loss: 2.0169e-04
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7440e-04 - val_loss: 2.0124e-04
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1155e-04 - val_loss: 2.0342e-04
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6609e-04 - val_loss: 1.9974e-04
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7605e-04 - val_loss: 2.0689e-04
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2985e-04 - val_loss: 2.0696e-04
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.2592e-04 - val_loss: 1.9407e-04
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1844e-04 - val_loss: 1.9740e-04
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7049e-04 - val_loss: 2.0592e-04
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8705e-04 - val_loss: 1.9151e-04
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9530e-04 - val_loss: 3.2211e-04
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3281e-04 - val_loss: 2.1066e-04
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8074e-04 - val_loss: 2.1417e-04
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.2327e-04 - val_loss: 2.0008e-04
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3376e-04 - val_loss: 2.4363e-04
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2289e-04 - val_loss: 2.0916e-04
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9389e-04 - val_loss: 1.9014e-04
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6029e-04 - val_loss: 1.8541e-04
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2695e-04 - val_loss: 1.7820e-04
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.1892e-04 - val_loss: 2.2650e-04
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9382e-04 - val_loss: 2.7342e-04
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8057e-04 - val_loss: 1.8813e-04
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3059e-04 - val_loss: 1.6525e-04
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5278e-04 - val_loss: 1.6938e-04
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5934e-04 - val_loss: 1.6992e-04
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.8632e-04 - val_loss: 1.8728e-04
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.9622e-04 - val_loss: 1.8327e-04
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.2409e-04 - val_loss: 1.6366e-04
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.1254e-04 - val_loss: 1.6620e-04
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.3299e-04 - val_loss: 1.9191e-04
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.5628e-04 - val_loss: 1.8635e-04
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1425e-04 - val_loss: 1.6493e-04
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.4164e-04 - val_loss: 1.7656e-04
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.6092 - val_loss: 0.0593
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0401 - val_loss: 0.0133
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0113 - val_loss: 0.0076
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0052 - val_loss: 0.0071
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0042 - val_loss: 0.0075
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0041 - val_loss: 0.0059
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036 - val_loss: 0.0057
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0037 - val_loss: 0.0053
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 0.0050
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0035 - val_loss: 0.0051
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0039 - val_loss: 0.0053
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - val_loss: 0.0045
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0032 - val_loss: 0.0044
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - val_loss: 0.0043
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0030 - val_loss: 0.0043
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0029 - val_loss: 0.0040
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029 - val_loss: 0.0040
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0028 - val_loss: 0.0047
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032 - val_loss: 0.0049
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - val_loss: 0.0039
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - val_loss: 0.0039
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030 - val_loss: 0.0040
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024 - val_loss: 0.0036
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0025 - val_loss: 0.0031
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0022 - val_loss: 0.0031
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0022 - val_loss: 0.0032
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0020 - val_loss: 0.0026
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0021 - val_loss: 0.0033
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0012 - val_loss: 0.0013

# %%
# 10. Dự báo dữ liệu test, val
dxg_train_predict=dxg_model.predict(dxg_X_train)
dxg_y_pred=dxg_model.predict(dxg_X_test)
dxg_y_pred_val=dxg_model.predict(dxg_X_val)

qcg_train_predict=qcg_model.predict(qcg_X_train)
qcg_y_pred=qcg_model.predict(qcg_X_test)
qcg_y_pred_val=qcg_model.predict(qcg_X_val)

vhm_train_predict=vhm_model.predict(vhm_X_train)
vhm_y_pred=vhm_model.predict(vhm_X_test)
vhm_y_pred_val=vhm_model.predict(vhm_X_val)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
dxg_train_predict=scaler.inverse_transform(dxg_train_predict)
dxg_y_pred=scaler.inverse_transform(dxg_y_pred)
dxg_y_pred_val=scaler.inverse_transform(dxg_y_pred_val)

qcg_train_predict=scaler.inverse_transform(qcg_train_predict)
qcg_y_pred=scaler.inverse_transform(qcg_y_pred)
qcg_y_pred_val=scaler.inverse_transform(qcg_y_pred_val)

vhm_train_predict=scaler.inverse_transform(vhm_train_predict)
vhm_y_pred=scaler.inverse_transform(vhm_y_pred)
vhm_y_pred_val=scaler.inverse_transform(vhm_y_pred_val)
# Out:
# DXG
# Validation RMSE: 50267.3029328896
# Testing RMSE: 45345.84238764327
#
#
# QCG
# Validation RMSE: 43657.873625661516
# Testing RMSE: 41885.00264460522
#
#
# VHM
# Validation RMSE: 69026.39834263764
# Testing RMSE: 64661.01507075175

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
dxg_valid_rmse = np.sqrt(np.mean((dxg_y_pred_val - dxg_yval)**2))
dxg_test_rmse = np.sqrt(np.mean((dxg_y_pred - dxg_ytest)**2))

qcg_valid_rmse = np.sqrt(np.mean((qcg_y_pred_val - qcg_yval)**2))
qcg_test_rmse = np.sqrt(np.mean((qcg_y_pred - qcg_ytest)**2))

vhm_valid_rmse = np.sqrt(np.mean((vhm_y_pred_val - vhm_yval)**2))
vhm_test_rmse = np.sqrt(np.mean((vhm_y_pred - vhm_ytest)**2))

print('DXG')
print('Validation RMSE:', dxg_valid_rmse)
print('Testing RMSE:', dxg_test_rmse)
print('\n')

print('QCG')
print('Validation RMSE:', qcg_valid_rmse)
print('Testing RMSE:', qcg_test_rmse)
print('\n')

print('VHM')
print('Validation RMSE:', vhm_valid_rmse)
print('Testing RMSE:', vhm_test_rmse)
# Out:
# DXG
# Validation RMSE: 50267.3029328896
# Testing RMSE: 45345.84238764327
#
#
# QCG
# Validation RMSE: 43657.873625661516
# Testing RMSE: 41885.00264460522
#
#
# VHM
# Validation RMSE: 69026.39834263764
# Testing RMSE: 64661.01507075175

# %%
# 13. Dự báo 30 ngày tiếp theo
x_input=dxg_val_data[60:].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

dxg_lst_output=[]
n_steps=66
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = dxg_model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        dxg_lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = dxg_model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        dxg_lst_output.extend(yhat.tolist())
        i=i+1
# Out:
# [0.256501]
# 67
# [0.256501]
# 68
# [0.256501]
# 69
# [0.256501]
# 70
# [0.256501]
# 71
# [0.256501]
# 72
# [0.256501]
# 73
# [0.256501]
# 74
# [0.256501]
# 75
# [0.256501]
# 76
# [0.256501]
# 77
# [0.256501]
# 78
# [0.256501]
# 79
# [0.256501]
# 80
# [0.256501]
# 81
# [0.256501]
# 82
# [0.256501]
# 83
# [0.256501]
# 84
# [0.256501]
# 85
# [0.256501]
# 86
# [0.256501]
# 87
# [0.256501]
# 88
# [0.256501]
# 89
# [0.256501]
# 90
# [0.256501]
# 91
# [0.256501]
# 92
# [0.256501]
# 93
# [0.256501]
# 94
# [0.256501]
# 95
# [0.256501]
# 96

# %%
# 13. Dự báo 30 ngày tiếp theo
x_input=qcg_val_data[60:].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

qcg_lst_output=[]
n_steps=66
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = qcg_model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        qcg_lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = qcg_model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        qcg_lst_output.extend(yhat.tolist())
        i=i+1
# Out:
# [0.06295779]
# 67
# [0.06295779]
# 68
# [0.06295779]
# 69
# [0.06295779]
# 70
# [0.06295779]
# 71
# [0.06295779]
# 72
# [0.06295779]
# 73
# [0.06295779]
# 74
# [0.06295779]
# 75
# [0.06295779]
# 76
# [0.06295779]
# 77
# [0.06295779]
# 78
# [0.06295779]
# 79
# [0.06295779]
# 80
# [0.06295779]
# 81
# [0.06295779]
# 82
# [0.06295779]
# 83
# [0.06295779]
# 84
# [0.06295779]
# 85
# [0.06295779]
# 86
# [0.06295779]
# 87
# [0.06295779]
# 88
# [0.06295779]
# 89
# [0.06295779]
# 90
# [0.06295779]
# 91
# [0.06295779]
# 92
# [0.06295779]
# 93
# [0.06295779]
# 94
# [0.06295779]
# 95
# [0.06295779]
# 96

# %%
# 13. Dự báo 30 ngày tiếp theo
x_input=vhm_val_data[60:].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

vhm_lst_output=[]
n_steps=66
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = vhm_model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        vhm_lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = vhm_model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        vhm_lst_output.extend(yhat.tolist())
        i=i+1
# Out:
# [0.6079317]
# 67
# [0.6079317]
# 68
# [0.6079317]
# 69
# [0.6079317]
# 70
# [0.6079317]
# 71
# [0.6079317]
# 72
# [0.6079317]
# 73
# [0.6079317]
# 74
# [0.6079317]
# 75
# [0.6079317]
# 76
# [0.6079317]
# 77
# [0.6079317]
# 78
# [0.6079317]
# 79
# [0.6079317]
# 80
# [0.6079317]
# 81
# [0.6079317]
# 82
# [0.6079317]
# 83
# [0.6079317]
# 84
# [0.6079317]
# 85
# [0.6079317]
# 86
# [0.6079317]
# 87
# [0.6079317]
# 88
# [0.6079317]
# 89
# [0.6079317]
# 90
# [0.6079317]
# 91
# [0.6079317]
# 92
# [0.6079317]
# 93
# [0.6079317]
# 94
# [0.6079317]
# 95
# [0.6079317]
# 96

# %%
# 14.Vẽ hình
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

#DXG
dxg_train_data_index = pd.RangeIndex(start=0, stop=dxg_train_size, step=1)
axs[0].plot(scaler.inverse_transform(dxg_train_data))
dxg_test_data_index = pd.RangeIndex(start=dxg_train_size, stop=dxg_train_size+dxg_test_size, step=1)
axs[0].plot(dxg_test_data_index,scaler.inverse_transform(dxg_test_data))
dxg_test_data_index = pd.RangeIndex(start=dxg_train_size+101, stop=dxg_train_size+dxg_test_size, step=1)
axs[0].plot(dxg_test_data_index,(dxg_y_pred))
dxg_val_data_index = pd.RangeIndex(start=dxg_train_size+dxg_test_size, stop=dxg_train_size+dxg_test_size+dxg_val_size, step=1)
axs[0].plot(dxg_val_data_index,scaler.inverse_transform(dxg_val_data))
dxg_val_data_index = pd.RangeIndex(start=dxg_train_size+dxg_test_size+101, stop=dxg_train_size+dxg_test_size+dxg_val_size, step=1)
axs[0].plot(dxg_val_data_index,dxg_y_pred_val)
dxg_predict_data_index = pd.RangeIndex(start=len(dxg1)-1, stop=len(dxg1)+29, step=1)
axs[0].plot(dxg_predict_data_index,scaler.inverse_transform(dxg_lst_output))
axs[0].legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])


#QCG
qcg_train_data_index = pd.RangeIndex(start=0, stop=qcg_train_size, step=1)
axs[1].plot(scaler.inverse_transform(qcg_train_data))
qcg_test_data_index = pd.RangeIndex(start=qcg_train_size, stop=qcg_train_size+qcg_test_size, step=1)
axs[1].plot(qcg_test_data_index,scaler.inverse_transform(qcg_test_data))
qcg_test_data_index = pd.RangeIndex(start=qcg_train_size+101, stop=qcg_train_size+qcg_test_size, step=1)
axs[1].plot(qcg_test_data_index,(qcg_y_pred))
qcg_val_data_index = pd.RangeIndex(start=qcg_train_size+qcg_test_size, stop=qcg_train_size+qcg_test_size+qcg_val_size, step=1)
axs[1].plot(qcg_val_data_index,scaler.inverse_transform(qcg_val_data))
qcg_val_data_index = pd.RangeIndex(start=qcg_train_size+qcg_test_size+101, stop=qcg_train_size+qcg_test_size+qcg_val_size, step=1)
axs[1].plot(qcg_val_data_index,qcg_y_pred_val)
qcg_predict_data_index = pd.RangeIndex(start=len(qcg1)-1, stop=len(qcg1)+29, step=1)
axs[1].plot(qcg_predict_data_index,scaler.inverse_transform(qcg_lst_output))
axs[1].legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])

#VHM
vhm_train_data_index = pd.RangeIndex(start=0, stop=vhm_train_size, step=1)
axs[2].plot(scaler.inverse_transform(vhm_train_data))
vhm_test_data_index = pd.RangeIndex(start=vhm_train_size, stop=vhm_train_size+vhm_test_size, step=1)
axs[2].plot(vhm_test_data_index,scaler.inverse_transform(vhm_test_data))
vhm_test_data_index = pd.RangeIndex(start=vhm_train_size+101, stop=vhm_train_size+vhm_test_size, step=1)
axs[2].plot(vhm_test_data_index,(vhm_y_pred))
vhm_val_data_index = pd.RangeIndex(start=vhm_train_size+vhm_test_size, stop=vhm_train_size+vhm_test_size+vhm_val_size, step=1)
axs[2].plot(vhm_val_data_index,scaler.inverse_transform(vhm_val_data))
vhm_val_data_index = pd.RangeIndex(start=vhm_train_size+vhm_test_size+101, stop=vhm_train_size+vhm_test_size+vhm_val_size, step=1)
axs[2].plot(vhm_val_data_index,vhm_y_pred_val)
vhm_predict_data_index = pd.RangeIndex(start=len(vhm1)-1, stop=len(vhm1)+29, step=1)
axs[2].plot(vhm_predict_data_index,scaler.inverse_transform(vhm_lst_output))
axs[2].legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])


axs[0].set_xlabel('DXG',fontsize=20)
axs[1].set_xlabel('QCG',fontsize=20)
axs[2].set_xlabel('VHM',fontsize=20)
plt.tight_layout()
plt.show()
