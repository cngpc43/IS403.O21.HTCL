# %% [markdown]
# DXG

# %%
# 1. Import thư viện cần thiết

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU

# %%
# 1. Import thư viện cần thiết

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, GRU

# %%
# 2. Đọc file csv và gắng index với giá Close
dxg = pd.read_csv('./DATA/DXG.csv')
qcg = pd.read_csv('./DATA/QCG.csv')
vhm = pd.read_csv('./DATA/VHM.csv')

def remove_commas_and_convert(x):
    return float(x.replace(',', ''))
# Áp dụng hàm cho toàn bộ DataFrame
dxg = dxg['Close'].apply(remove_commas_and_convert)
qcg = qcg['Close'].apply(remove_commas_and_convert)
vhm = vhm['Close'].apply(remove_commas_and_convert)

dxg1=dxg.reset_index()['Close']
qcg1=qcg.reset_index()['Close']
vhm1=vhm.reset_index()['Close']

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))

dxg1=scaler.fit_transform(np.array(dxg1).reshape(-1,1))
qcg1=scaler.fit_transform(np.array(qcg1).reshape(-1,1))
vhm1=scaler.fit_transform(np.array(vhm1).reshape(-1,1))

# %%
# 4. Chia train test
#DXG
dxg_train_size = int(0.7 * len(dxg1))
dxg_test_size = int(0.2 * len(dxg1))
dxg_val_size = len(dxg1) - dxg_train_size - dxg_test_size
dxg_train_data = dxg1[:dxg_train_size]
dxg_test_data = dxg1[dxg_train_size:dxg_train_size+dxg_test_size]
dxg_val_data = dxg1[dxg_train_size+dxg_test_size:]

#QCG
qcg_train_size = int(0.7 * len(qcg1))
qcg_test_size = int(0.2 * len(qcg1))
qcg_val_size = len(qcg1) - qcg_train_size - qcg_test_size
qcg_train_data = qcg1[:qcg_train_size]
qcg_test_data = qcg1[qcg_train_size:qcg_train_size+qcg_test_size]
qcg_val_data = qcg1[qcg_train_size+qcg_test_size:]

#VHM
vhm_train_size = int(0.7 * len(vhm1))
vhm_test_size = int(0.2 * len(vhm1))
vhm_val_size = len(vhm1) - vhm_train_size - vhm_test_size
vhm_train_data = vhm1[:vhm_train_size]
vhm_test_data = vhm1[vhm_train_size:vhm_train_size+vhm_test_size]
vhm_val_data = vhm1[vhm_train_size+vhm_test_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
#DXG
time_step = 100
dxg_X_train, dxg_y_train = create_dataset(dxg_train_data, time_step)
dxg_X_val, dxg_yval = create_dataset(dxg_val_data, time_step)
dxg_X_test, dxg_ytest = create_dataset(dxg_test_data, time_step)

#QCG
qcg_X_train, qcg_y_train = create_dataset(qcg_train_data, time_step)
qcg_X_val, qcg_yval = create_dataset(qcg_val_data, time_step)
qcg_X_test, qcg_ytest = create_dataset(qcg_test_data, time_step)


#VHM
vhm_X_train, vhm_y_train = create_dataset(vhm_train_data, time_step)
vhm_X_val, vhm_yval = create_dataset(vhm_val_data, time_step)
vhm_X_test, vhm_ytest = create_dataset(vhm_test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
dxg_X_train =dxg_X_train.reshape(dxg_X_train.shape[0],dxg_X_train.shape[1] , 1)
dxg_X_test = dxg_X_test.reshape(dxg_X_test.shape[0],dxg_X_test.shape[1] , 1)
dxg_X_val = dxg_X_val.reshape(dxg_X_val.shape[0],dxg_X_val.shape[1] , 1)

qcg_X_train =qcg_X_train.reshape(qcg_X_train.shape[0],qcg_X_train.shape[1] , 1)
qcg_X_test = qcg_X_test.reshape(qcg_X_test.shape[0],qcg_X_test.shape[1] , 1)
qcg_X_val = qcg_X_val.reshape(qcg_X_val.shape[0],qcg_X_val.shape[1] , 1)

vhm_X_train =vhm_X_train.reshape(vhm_X_train.shape[0],vhm_X_train.shape[1] , 1)
vhm_X_test = vhm_X_test.reshape(vhm_X_test.shape[0],vhm_X_test.shape[1] , 1)
vhm_X_val = vhm_X_val.reshape(vhm_X_val.shape[0],vhm_X_val.shape[1] , 1)

# %%
# 8. Define GRU Model

dxg_model = Sequential()
dxg_model.add(GRU(64, input_shape=(time_step, 1)))
dxg_model.add(Dense(1))
dxg_model.compile(optimizer='adam', loss='mean_squared_error')

qcg_model = Sequential()
qcg_model.add(GRU(64, input_shape=(time_step, 1)))
qcg_model.add(Dense(1))
qcg_model.compile(optimizer='adam', loss='mean_squared_error')

vhm_model = Sequential()
vhm_model.add(GRU(64, input_shape=(time_step, 1)))
vhm_model.add(Dense(1))
vhm_model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# c:\Users\Khang\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 9. Fit mô hình với dữ liệu train
dxg_model.fit(dxg_X_train,dxg_y_train,validation_data=(dxg_X_test,dxg_ytest),epochs=100,batch_size=64,verbose=1)
qcg_model.fit(qcg_X_train,qcg_y_train,validation_data=(qcg_X_test,qcg_ytest),epochs=100,batch_size=64,verbose=1)
vhm_model.fit(vhm_X_train,vhm_y_train,validation_data=(vhm_X_test,vhm_ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.1950 - val_loss: 0.0090
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0233 - val_loss: 0.0397
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0167 - val_loss: 0.0084
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0097 - val_loss: 0.0069
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0045 - val_loss: 0.0027
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0021 - val_loss: 4.0343e-04
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0014 - val_loss: 2.0183e-04
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0014 - val_loss: 2.2815e-04
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0013 - val_loss: 2.2630e-04
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0012 - val_loss: 1.9062e-04
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0012 - val_loss: 2.0952e-04
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0011 - val_loss: 1.8295e-04
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0010 - val_loss: 1.9068e-04
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0010 - val_loss: 1.8146e-04
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 9.7952e-04 - val_loss: 1.7511e-04
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0010 - val_loss: 1.8799e-04
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0010 - val_loss: 1.7464e-04
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0010 - val_loss: 1.7912e-04
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 9.3188e-04 - val_loss: 1.6653e-04
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 9.8189e-04 - val_loss: 1.7682e-04
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 9.1333e-04 - val_loss: 1.6730e-04
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 8.9128e-04 - val_loss: 1.7182e-04
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 8.4231e-04 - val_loss: 1.6054e-04
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 9.0751e-04 - val_loss: 1.6006e-04
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.5442e-04 - val_loss: 1.5736e-04
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 8.1466e-04 - val_loss: 1.5648e-04
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 7.4737e-04 - val_loss: 1.7028e-04
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.3364e-04 - val_loss: 1.8946e-04
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 8.6023e-04 - val_loss: 1.5207e-04
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.3280e-04 - val_loss: 1.5175e-04
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.6218e-04 - val_loss: 1.4909e-04
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.0634e-04 - val_loss: 1.5363e-04
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 7.0544e-04 - val_loss: 1.4743e-04
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 6.6305e-04 - val_loss: 1.4851e-04
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 6.6655e-04 - val_loss: 1.4657e-04
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 7.4201e-04 - val_loss: 1.4524e-04
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 7.2799e-04 - val_loss: 1.5025e-04
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 6.8529e-04 - val_loss: 1.4296e-04
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 6.6895e-04 - val_loss: 1.3919e-04
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 6.4184e-04 - val_loss: 1.3873e-04
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 6.4525e-04 - val_loss: 1.3984e-04
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 6.9093e-04 - val_loss: 1.3946e-04
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 7.0005e-04 - val_loss: 1.5548e-04
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 7.1837e-04 - val_loss: 1.6460e-04
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 7.4192e-04 - val_loss: 1.4979e-04
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 6.4374e-04 - val_loss: 1.3455e-04
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 6.6639e-04 - val_loss: 1.3404e-04
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 6.5906e-04 - val_loss: 1.7381e-04
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 6.7298e-04 - val_loss: 1.3611e-04
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 6.5770e-04 - val_loss: 1.3306e-04
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 6.5608e-04 - val_loss: 1.3739e-04
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 7.6888e-04 - val_loss: 1.4468e-04
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 6.7608e-04 - val_loss: 1.6810e-04
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 6.2177e-04 - val_loss: 1.2943e-04
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 6.2413e-04 - val_loss: 1.3746e-04
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.6298e-04 - val_loss: 1.2838e-04
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 6.6659e-04 - val_loss: 1.3128e-04
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.2692e-04 - val_loss: 1.4887e-04
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.1335e-04 - val_loss: 1.2239e-04
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.0984e-04 - val_loss: 1.2462e-04
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 5.6961e-04 - val_loss: 1.2549e-04
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.4919e-04 - val_loss: 1.2480e-04
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.8548e-04 - val_loss: 1.1994e-04
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 6.0613e-04 - val_loss: 1.2297e-04
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.8189e-04 - val_loss: 1.2246e-04
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 5.3693e-04 - val_loss: 1.2526e-04
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 5.8218e-04 - val_loss: 1.2389e-04
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 6.4725e-04 - val_loss: 1.3417e-04
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - loss: 5.9881e-04 - val_loss: 1.2007e-04
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 5.6501e-04 - val_loss: 1.2933e-04
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 5.4109e-04 - val_loss: 1.3910e-04
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5.6391e-04 - val_loss: 1.1442e-04
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 5.8202e-04 - val_loss: 1.1643e-04
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 5.6165e-04 - val_loss: 1.1434e-04
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 5.2332e-04 - val_loss: 1.2504e-04
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 5.4862e-04 - val_loss: 1.1237e-04
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.1247e-04 - val_loss: 1.1237e-04
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 5.1452e-04 - val_loss: 1.1451e-04
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 5.1693e-04 - val_loss: 1.1337e-04
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 5.6711e-04 - val_loss: 1.1005e-04
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 5.6270e-04 - val_loss: 1.0850e-04
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 5.1912e-04 - val_loss: 1.0774e-04
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 5.4283e-04 - val_loss: 1.0923e-04
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 5.1408e-04 - val_loss: 1.2223e-04
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 4.5206e-04 - val_loss: 1.0619e-04
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 5.4739e-04 - val_loss: 1.0612e-04
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 5.2617e-04 - val_loss: 1.2092e-04
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.9034e-04 - val_loss: 1.0878e-04
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 5.6663e-04 - val_loss: 1.1487e-04
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 5.0289e-04 - val_loss: 1.0400e-04
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 4.8707e-04 - val_loss: 1.0355e-04
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 4.8636e-04 - val_loss: 1.0784e-04
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 5.0014e-04 - val_loss: 1.0067e-04
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 4.7695e-04 - val_loss: 9.9797e-05
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 4.7465e-04 - val_loss: 1.0645e-04
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.9456e-04 - val_loss: 1.0843e-04
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 5.3906e-04 - val_loss: 1.7971e-04
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 6.0178e-04 - val_loss: 1.1216e-04
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 5.5053e-04 - val_loss: 1.1471e-04
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 4.8931e-04 - val_loss: 1.0291e-04
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0357 - val_loss: 0.0203
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0077 - val_loss: 0.0023
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0015 - val_loss: 6.0513e-04
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0011 - val_loss: 5.7841e-04
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 9.9957e-04 - val_loss: 5.2545e-04
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.9298e-04 - val_loss: 5.7367e-04
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.7125e-04 - val_loss: 5.2273e-04
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0010 - val_loss: 4.6743e-04
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.9179e-04 - val_loss: 4.8352e-04
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 7.9899e-04 - val_loss: 5.0460e-04
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.8965e-04 - val_loss: 4.2305e-04
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.7003e-04 - val_loss: 4.4207e-04
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.5637e-04 - val_loss: 4.2276e-04
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 7.6695e-04 - val_loss: 3.9525e-04
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.9478e-04 - val_loss: 3.6791e-04
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.2818e-04 - val_loss: 3.7375e-04
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.3599e-04 - val_loss: 3.8219e-04
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 7.1435e-04 - val_loss: 3.3921e-04
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 7.1766e-04 - val_loss: 3.7225e-04
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 7.8310e-04 - val_loss: 3.3269e-04
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.9319e-04 - val_loss: 3.0953e-04
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.2024e-04 - val_loss: 4.3064e-04
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.0144e-04 - val_loss: 2.9408e-04
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 7.1332e-04 - val_loss: 2.8845e-04
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 5.9216e-04 - val_loss: 2.8750e-04
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.0533e-04 - val_loss: 2.8212e-04
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 5.7586e-04 - val_loss: 3.2352e-04
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.7370e-04 - val_loss: 2.8641e-04
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 5.8312e-04 - val_loss: 2.5489e-04
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 5.7966e-04 - val_loss: 2.8296e-04
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 5.6678e-04 - val_loss: 2.6198e-04
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 5.9440e-04 - val_loss: 3.4332e-04
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 5.5770e-04 - val_loss: 2.7257e-04
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 6.0086e-04 - val_loss: 2.5266e-04
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 5.8690e-04 - val_loss: 2.5666e-04
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 6.3429e-04 - val_loss: 2.1922e-04
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 5.5948e-04 - val_loss: 2.1115e-04
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 4.8519e-04 - val_loss: 2.2407e-04
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 4.8492e-04 - val_loss: 2.0884e-04
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 5.5187e-04 - val_loss: 2.1156e-04
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 5.4002e-04 - val_loss: 2.1002e-04
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 4.8936e-04 - val_loss: 2.0084e-04
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 5.0164e-04 - val_loss: 2.0252e-04
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.9650e-04 - val_loss: 2.2083e-04
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 5.2298e-04 - val_loss: 1.8420e-04
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 4.6976e-04 - val_loss: 1.7993e-04
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 5.0037e-04 - val_loss: 1.7988e-04
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.4638e-04 - val_loss: 2.1820e-04
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 4.5680e-04 - val_loss: 1.8336e-04
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.0068e-04 - val_loss: 1.9965e-04
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 5.4029e-04 - val_loss: 1.6800e-04
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 5.1417e-04 - val_loss: 1.7682e-04
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.7814e-04 - val_loss: 1.6961e-04
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 4.5779e-04 - val_loss: 1.9553e-04
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 4.4746e-04 - val_loss: 1.6693e-04
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 4.6050e-04 - val_loss: 1.7021e-04
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 4.5290e-04 - val_loss: 1.6206e-04
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 4.6262e-04 - val_loss: 1.5988e-04
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 4.9794e-04 - val_loss: 1.4837e-04
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.6481e-04 - val_loss: 1.5393e-04
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 4.1300e-04 - val_loss: 1.4997e-04
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4.4961e-04 - val_loss: 1.4973e-04
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 3.9441e-04 - val_loss: 1.6837e-04
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.4048e-04 - val_loss: 1.5440e-04
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 4.5342e-04 - val_loss: 1.4811e-04
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 4.5680e-04 - val_loss: 1.6476e-04
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 4.1765e-04 - val_loss: 1.4773e-04
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.3873e-04 - val_loss: 2.0819e-04
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.4524e-04 - val_loss: 1.4997e-04
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 4.8699e-04 - val_loss: 2.1559e-04
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 5.5791e-04 - val_loss: 1.5221e-04
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 4.6578e-04 - val_loss: 1.4615e-04
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.7801e-04 - val_loss: 1.4861e-04
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.5746e-04 - val_loss: 1.3541e-04
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.9225e-04 - val_loss: 1.4714e-04
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.2964e-04 - val_loss: 1.3697e-04
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.1858e-04 - val_loss: 1.3918e-04
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.5099e-04 - val_loss: 1.3506e-04
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.7481e-04 - val_loss: 1.3872e-04
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.9568e-04 - val_loss: 1.4179e-04
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.4690e-04 - val_loss: 1.5979e-04
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.4339e-04 - val_loss: 1.2988e-04
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 3.9963e-04 - val_loss: 1.2165e-04
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.7468e-04 - val_loss: 1.2829e-04
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 4.0306e-04 - val_loss: 1.3115e-04
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.0167e-04 - val_loss: 1.2697e-04
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.8565e-04 - val_loss: 1.2108e-04
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.0380e-04 - val_loss: 1.2738e-04
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.3190e-04 - val_loss: 1.8543e-04
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.5467e-04 - val_loss: 1.3496e-04
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.4657e-04 - val_loss: 1.2001e-04
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.0107e-04 - val_loss: 1.2621e-04
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.9427e-04 - val_loss: 1.2233e-04
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.6024e-04 - val_loss: 1.6213e-04
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.9073e-04 - val_loss: 1.2581e-04
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 4.5736e-04 - val_loss: 1.2283e-04
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 3.9206e-04 - val_loss: 1.2053e-04
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 4.2925e-04 - val_loss: 1.2287e-04
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.1459e-04 - val_loss: 1.2082e-04
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.2040 - val_loss: 0.0055
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0156 - val_loss: 0.0084
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0104 - val_loss: 0.0046
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0083 - val_loss: 0.0029
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0050 - val_loss: 0.0022
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 9.9987e-04 - val_loss: 0.0013
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.9000e-04 - val_loss: 0.0012
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 9.2256e-04 - val_loss: 0.0012
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 9.6716e-04 - val_loss: 0.0013
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 9.9876e-04 - val_loss: 0.0012
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 9.4786e-04 - val_loss: 0.0012
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 8.7860e-04 - val_loss: 0.0011
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 9.4619e-04 - val_loss: 0.0011
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 9.2117e-04 - val_loss: 0.0011
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 9.0435e-04 - val_loss: 0.0011
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 9.7354e-04 - val_loss: 0.0011
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 8.8289e-04 - val_loss: 0.0011
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 9.0100e-04 - val_loss: 0.0011
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 8.9753e-04 - val_loss: 0.0011
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.9228e-04 - val_loss: 0.0011
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 9.2990e-04 - val_loss: 0.0010
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 9.2695e-04 - val_loss: 0.0010
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 8.8200e-04 - val_loss: 0.0010
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.9739e-04 - val_loss: 9.9989e-04
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 8.5350e-04 - val_loss: 9.8460e-04
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 8.1502e-04 - val_loss: 9.9525e-04
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 8.3283e-04 - val_loss: 9.7569e-04
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.4843e-04 - val_loss: 9.7688e-04
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.9401e-04 - val_loss: 9.6477e-04
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.7626e-04 - val_loss: 9.5946e-04
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.7060e-04 - val_loss: 9.7260e-04
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.2560e-04 - val_loss: 9.5223e-04
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 8.7227e-04 - val_loss: 9.6371e-04
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 8.4170e-04 - val_loss: 9.2204e-04
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 8.2395e-04 - val_loss: 9.1980e-04
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.5852e-04 - val_loss: 9.2177e-04
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.6437e-04 - val_loss: 9.1522e-04
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 9.0936e-04 - val_loss: 9.0462e-04
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.3831e-04 - val_loss: 9.6881e-04
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.9932e-04 - val_loss: 9.3633e-04
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 8.4871e-04 - val_loss: 8.8898e-04
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.4710e-04 - val_loss: 9.2751e-04
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 8.3618e-04 - val_loss: 8.8476e-04
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.7165e-04 - val_loss: 8.7429e-04
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 8.5243e-04 - val_loss: 9.0121e-04
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 7.8270e-04 - val_loss: 8.9891e-04
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.4090e-04 - val_loss: 9.7484e-04
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.3592e-04 - val_loss: 9.6227e-04
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 7.9610e-04 - val_loss: 8.6756e-04
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 7.8415e-04 - val_loss: 8.6865e-04
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 7.6653e-04 - val_loss: 8.5809e-04
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 7.4532e-04 - val_loss: 8.7757e-04
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 7.8512e-04 - val_loss: 8.4755e-04
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 7.6550e-04 - val_loss: 8.5042e-04
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 8.3315e-04 - val_loss: 8.3583e-04
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 8.1350e-04 - val_loss: 8.3605e-04
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.3840e-04 - val_loss: 8.4474e-04
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 7.9235e-04 - val_loss: 8.2122e-04
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.1167e-04 - val_loss: 8.3375e-04
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 7.5673e-04 - val_loss: 8.4050e-04
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 7.6494e-04 - val_loss: 8.0838e-04
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 7.0540e-04 - val_loss: 8.0493e-04
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 8.4005e-04 - val_loss: 8.0175e-04
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 8.0517e-04 - val_loss: 7.9950e-04
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 7.8744e-04 - val_loss: 8.0966e-04
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 7.5180e-04 - val_loss: 8.2298e-04
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 7.1170e-04 - val_loss: 7.9728e-04
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 7.5747e-04 - val_loss: 8.5304e-04
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 7.8556e-04 - val_loss: 8.2785e-04
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 7.4119e-04 - val_loss: 8.4208e-04
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 8.9714e-04 - val_loss: 8.4926e-04
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 8.2434e-04 - val_loss: 8.8578e-04
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.9481e-04 - val_loss: 9.7992e-04
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 8.0804e-04 - val_loss: 9.7594e-04
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 8.8208e-04 - val_loss: 7.7472e-04
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 6.9298e-04 - val_loss: 7.7962e-04
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 7.0708e-04 - val_loss: 7.8154e-04
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 7.1477e-04 - val_loss: 7.9330e-04
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 7.2844e-04 - val_loss: 7.8391e-04

# %%
# 10. Dự báo dữ liệu test, val
dxg_train_predict=dxg_model.predict(dxg_X_train)
dxg_y_pred=dxg_model.predict(dxg_X_test)
dxg_y_pred_val=dxg_model.predict(dxg_X_val)

qcg_train_predict=qcg_model.predict(qcg_X_train)
qcg_y_pred=qcg_model.predict(qcg_X_test)
qcg_y_pred_val=qcg_model.predict(qcg_X_val)

vhm_train_predict=vhm_model.predict(vhm_X_train)
vhm_y_pred=vhm_model.predict(vhm_X_test)
vhm_y_pred_val=vhm_model.predict(vhm_X_val)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
# 11. Chuẩn hóa dữ liệu y_pred, y_pred_val
dxg_train_predict=scaler.inverse_transform(dxg_train_predict)
dxg_y_pred=scaler.inverse_transform(dxg_y_pred)
dxg_y_pred_val=scaler.inverse_transform(dxg_y_pred_val)

qcg_train_predict=scaler.inverse_transform(qcg_train_predict)
qcg_y_pred=scaler.inverse_transform(qcg_y_pred)
qcg_y_pred_val=scaler.inverse_transform(qcg_y_pred_val)

vhm_train_predict=scaler.inverse_transform(vhm_train_predict)
vhm_y_pred=scaler.inverse_transform(vhm_y_pred)
vhm_y_pred_val=scaler.inverse_transform(vhm_y_pred_val)

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
dxg_valid_rmse = np.sqrt(np.mean((dxg_y_pred_val - dxg_yval)**2))
dxg_test_rmse = np.sqrt(np.mean((dxg_y_pred - dxg_ytest)**2))

qcg_valid_rmse = np.sqrt(np.mean((qcg_y_pred_val - qcg_yval)**2))
qcg_test_rmse = np.sqrt(np.mean((qcg_y_pred - qcg_ytest)**2))

vhm_valid_rmse = np.sqrt(np.mean((vhm_y_pred_val - vhm_yval)**2))
vhm_test_rmse = np.sqrt(np.mean((vhm_y_pred - vhm_ytest)**2))

print('DXG')
print('Validation RMSE:', dxg_valid_rmse)
print('Testing RMSE:', dxg_test_rmse)
print('\n')

print('QCG')
print('Validation RMSE:', qcg_valid_rmse)
print('Testing RMSE:', qcg_test_rmse)
print('\n')

print('VHM')
print('Validation RMSE:', vhm_valid_rmse)
print('Testing RMSE:', vhm_test_rmse)
# Out:
# DXG
# Validation RMSE: 50112.57397654427
# Testing RMSE: 45179.31996112549
#
#
# QCG
# Validation RMSE: 43786.623114812784
# Testing RMSE: 41964.66513756186
#
#
# VHM
# Validation RMSE: 68979.68407948404
# Testing RMSE: 64779.01536473976

# %%
# 13. Dự báo 30 ngày tiếp theo
x_input=dxg_val_data[60:].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

dxg_lst_output=[]
n_steps=66
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = dxg_model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        dxg_lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = dxg_model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        dxg_lst_output.extend(yhat.tolist())
        i=i+1
# Out:
# [0.2677017]
# 67
# [0.2677017]
# 68
# [0.2677017]
# 69
# [0.2677017]
# 70
# [0.2677017]
# 71
# [0.2677017]
# 72
# [0.2677017]
# 73
# [0.2677017]
# 74
# [0.2677017]
# 75
# [0.2677017]
# 76
# [0.2677017]
# 77
# [0.2677017]
# 78
# [0.2677017]
# 79
# [0.2677017]
# 80
# [0.2677017]
# 81
# [0.2677017]
# 82
# [0.2677017]
# 83
# [0.2677017]
# 84
# [0.2677017]
# 85
# [0.2677017]
# 86
# [0.2677017]
# 87
# [0.2677017]
# 88
# [0.2677017]
# 89
# [0.2677017]
# 90
# [0.2677017]
# 91
# [0.2677017]
# 92
# [0.2677017]
# 93
# [0.2677017]
# 94
# [0.2677017]
# 95
# [0.2677017]
# 96

# %%
# 13. Dự báo 30 ngày tiếp theo
x_input=qcg_val_data[60:].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

qcg_lst_output=[]
n_steps=66
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = qcg_model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        qcg_lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = qcg_model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        qcg_lst_output.extend(yhat.tolist())
        i=i+1
# Out:
# [0.07087062]
# 67
# [0.07087062]
# 68
# [0.07087062]
# 69
# [0.07087062]
# 70
# [0.07087062]
# 71
# [0.07087062]
# 72
# [0.07087062]
# 73
# [0.07087062]
# 74
# [0.07087062]
# 75
# [0.07087062]
# 76
# [0.07087062]
# 77
# [0.07087062]
# 78
# [0.07087062]
# 79
# [0.07087062]
# 80
# [0.07087062]
# 81
# [0.07087062]
# 82
# [0.07087062]
# 83
# [0.07087062]
# 84
# [0.07087062]
# 85
# [0.07087062]
# 86
# [0.07087062]
# 87
# [0.07087062]
# 88
# [0.07087062]
# 89
# [0.07087062]
# 90
# [0.07087062]
# 91
# [0.07087062]
# 92
# [0.07087062]
# 93
# [0.07087062]
# 94
# [0.07087062]
# 95
# [0.07087062]
# 96

# %%
# 13. Dự báo 30 ngày tiếp theo
x_input=vhm_val_data[60:].reshape(1,-1)
x_input.shape

temp_input=list(x_input)
temp_input=temp_input[0].tolist()

from numpy import array

vhm_lst_output=[]
n_steps=66
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = vhm_model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        vhm_lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = vhm_model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        vhm_lst_output.extend(yhat.tolist())
        i=i+1
# Out:
# [0.6018218]
# 67
# [0.6018218]
# 68
# [0.6018218]
# 69
# [0.6018218]
# 70
# [0.6018218]
# 71
# [0.6018218]
# 72
# [0.6018218]
# 73
# [0.6018218]
# 74
# [0.6018218]
# 75
# [0.6018218]
# 76
# [0.6018218]
# 77
# [0.6018218]
# 78
# [0.6018218]
# 79
# [0.6018218]
# 80
# [0.6018218]
# 81
# [0.6018218]
# 82
# [0.6018218]
# 83
# [0.6018218]
# 84
# [0.6018218]
# 85
# [0.6018218]
# 86
# [0.6018218]
# 87
# [0.6018218]
# 88
# [0.6018218]
# 89
# [0.6018218]
# 90
# [0.6018218]
# 91
# [0.6018218]
# 92
# [0.6018218]
# 93
# [0.6018218]
# 94
# [0.6018218]
# 95
# [0.6018218]
# 96

# %%
# 14.Vẽ hình
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

#DXG
dxg_train_data_index = pd.RangeIndex(start=0, stop=dxg_train_size, step=1)
axs[0].plot(scaler.inverse_transform(dxg_train_data))
dxg_test_data_index = pd.RangeIndex(start=dxg_train_size, stop=dxg_train_size+dxg_test_size, step=1)
axs[0].plot(dxg_test_data_index,scaler.inverse_transform(dxg_test_data))
dxg_test_data_index = pd.RangeIndex(start=dxg_train_size+101, stop=dxg_train_size+dxg_test_size, step=1)
axs[0].plot(dxg_test_data_index,(dxg_y_pred))
dxg_val_data_index = pd.RangeIndex(start=dxg_train_size+dxg_test_size, stop=dxg_train_size+dxg_test_size+dxg_val_size, step=1)
axs[0].plot(dxg_val_data_index,scaler.inverse_transform(dxg_val_data))
dxg_val_data_index = pd.RangeIndex(start=dxg_train_size+dxg_test_size+101, stop=dxg_train_size+dxg_test_size+dxg_val_size, step=1)
axs[0].plot(dxg_val_data_index,dxg_y_pred_val)
dxg_predict_data_index = pd.RangeIndex(start=len(dxg1)-1, stop=len(dxg1)+29, step=1)
axs[0].plot(dxg_predict_data_index,scaler.inverse_transform(dxg_lst_output))
axs[0].legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])


#QCG
qcg_train_data_index = pd.RangeIndex(start=0, stop=qcg_train_size, step=1)
axs[1].plot(scaler.inverse_transform(qcg_train_data))
qcg_test_data_index = pd.RangeIndex(start=qcg_train_size, stop=qcg_train_size+qcg_test_size, step=1)
axs[1].plot(qcg_test_data_index,scaler.inverse_transform(qcg_test_data))
qcg_test_data_index = pd.RangeIndex(start=qcg_train_size+101, stop=qcg_train_size+qcg_test_size, step=1)
axs[1].plot(qcg_test_data_index,(qcg_y_pred))
qcg_val_data_index = pd.RangeIndex(start=qcg_train_size+qcg_test_size, stop=qcg_train_size+qcg_test_size+qcg_val_size, step=1)
axs[1].plot(qcg_val_data_index,scaler.inverse_transform(qcg_val_data))
qcg_val_data_index = pd.RangeIndex(start=qcg_train_size+qcg_test_size+101, stop=qcg_train_size+qcg_test_size+qcg_val_size, step=1)
axs[1].plot(qcg_val_data_index,qcg_y_pred_val)
qcg_predict_data_index = pd.RangeIndex(start=len(qcg1)-1, stop=len(qcg1)+29, step=1)
axs[1].plot(qcg_predict_data_index,scaler.inverse_transform(qcg_lst_output))
axs[1].legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])

#VHM
vhm_train_data_index = pd.RangeIndex(start=0, stop=vhm_train_size, step=1)
axs[2].plot(scaler.inverse_transform(vhm_train_data))
vhm_test_data_index = pd.RangeIndex(start=vhm_train_size, stop=vhm_train_size+vhm_test_size, step=1)
axs[2].plot(vhm_test_data_index,scaler.inverse_transform(vhm_test_data))
vhm_test_data_index = pd.RangeIndex(start=vhm_train_size+101, stop=vhm_train_size+vhm_test_size, step=1)
axs[2].plot(vhm_test_data_index,(vhm_y_pred))
vhm_val_data_index = pd.RangeIndex(start=vhm_train_size+vhm_test_size, stop=vhm_train_size+vhm_test_size+vhm_val_size, step=1)
axs[2].plot(vhm_val_data_index,scaler.inverse_transform(vhm_val_data))
vhm_val_data_index = pd.RangeIndex(start=vhm_train_size+vhm_test_size+101, stop=vhm_train_size+vhm_test_size+vhm_val_size, step=1)
axs[2].plot(vhm_val_data_index,vhm_y_pred_val)
vhm_predict_data_index = pd.RangeIndex(start=len(vhm1)-1, stop=len(vhm1)+29, step=1)
axs[2].plot(vhm_predict_data_index,scaler.inverse_transform(vhm_lst_output))
axs[2].legend(['Train','Test','Predict','Validate','ValidatePred','Predict30days'])


axs[0].set_xlabel('DXG',fontsize=20)
axs[1].set_xlabel('QCG',fontsize=20)
axs[2].set_xlabel('VHM',fontsize=20)
plt.tight_layout()
plt.show()
